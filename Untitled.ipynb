# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.datasets import fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# ...
# 4423680/4422102 [==============================] - 4s 1us/step

# %%
label_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
plt.imshow(train_images[1])
plt.grid(False)
plt.colorbar()
plt.show()

# %%
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# %%
plt.figure(figsize=(8,10))
for i in range(30):
    plt.subplot(5, 6, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(label_names[train_labels[i]])

# %%
w, h = 28, 28
(train_images, x_valid) = train_images[5000:], train_images[:5000]
(train_labels, y_valid) = train_labels[5000:], train_labels[:5000]

train_images = train_images.reshape(train_images.shape[0], w, h, 1)
x_valid = x_valid.reshape(x_valid.shape[0], w, h, 1)
test_images = test_images.reshape(test_images.shape[0], w, h, 1)
train_labels = keras.utils.to_categorical(train_labels, 10)
y_valid = keras.utils.to_categorical(y_valid, 10)
test_labels = keras.utils.to_categorical(test_labels, 10)

# %%
from keras import models
from keras import layers

network = models.Sequential()

network.add(layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1)))
network.add(layers.MaxPooling2D(pool_size=2))
network.add(layers.Dropout(0.3))

network.add(layers.Conv2D(filters=16, kernel_size=2, padding='same', activation='relu'))
network.add(layers.MaxPooling2D(pool_size=2))
network.add(layers.Dropout(0.3))

network.add(layers.Flatten())
network.add(layers.Dense(128, activation='relu'))
network.add(layers.Dropout(0.5))
network.add(layers.Dense(10, activation='softmax'))

network.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12 (Conv2D)           (None, 28, 28, 32)        160
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 16)        2064
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 7, 7, 16)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 7, 7, 16)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 784)               0
# ...

# %%
network.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='model.weights.bets.hdf5', verbose=1, save_best_only=True)

network.fit(train_images, train_labels, epochs=1, batch_size=64, validation_data=(x_valid, y_valid), callbacks=[checkpointer])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-f9502bd95c30> in <module>
#       2 checkpointer = ModelCheckpoint(filepath='model.weights.bets.hdf5', verbose=1, save_best_only=True)
#       3
# ----> 4 network.fit(train_images, train_labels, epochs=1, batch_size=64, validation_data=(x_valid, y_valid), callbacks=[checkpointer])
#
# /usr/local/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ...

# %%
score = network.evaluate(test_images, test_labels, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.1

# %%
y_hat = network.predict(test_images)

figure = plt.figure(figsize=(20,8))
for i, index in enumerate(np.random.choice(test_images.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(test_images[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(test_labels[index])
    ax.set_title("{} ({})".format(label_names[predict_index], label_names[true_index]), 
                      color=("green" if predict_index == true_index else "red"))
